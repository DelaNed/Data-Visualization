# %%
## This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode
import plotly.graph_objects as go
init_notebook_mode(connected=True)

import folium
# from geopy.geocoders import Nominatim
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import math

import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec 

from matplotlib.offsetbox import AnchoredText
from mpl_toolkits.axes_grid1 import make_axes_locatable
from PIL import Image
from wordcloud import WordCloud

import json
import warnings
warnings.filterwarnings(action='ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
plt.rcParams['figure.dpi'] = 200 #high resolution

# %%
# params = {'figure.dpi':200, #high resolution,
#           'font.family':'serif',
#           'font.sans-serif':'Lucida Grande',
#           'legend.fontsize': '12',
#           'figure.figsize': (18, 8),
#          'axes.labelsize': '13',
#          'axes.titlesize':'16',
#          'xtick.labelsize':'12',
#          'ytick.labelsize':'12'}
# plt.rcParams.update(params)

# %%
data_21 = pd.read_csv('data/kaggle_survey_2021_responses.csv', low_memory=False)
data_21.shape
# Out:
# (25974, 369)

# %% [markdown]
# ## Read countries longitude and latitude

# %%
# countries lat and long
map_df = pd.read_csv('data/long_lat.csv')
map_df.head()
# Out:
#           Q3   Latitude   Longitude
# 0      India  22.351115   78.667743
# 1  Indonesia  -2.483383  117.890285
# 2   Pakistan  30.330840   71.247499
# 3     Mexico  22.500048 -100.000037
# 4     Russia  64.686314   97.745306

# %% [markdown]
# ## Check the data

# %%
data_21.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                  Bachelor’s degree
# 2                                    Master’s degree
# 3                                    Master’s degree
# 4                                    Doctoral degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                              Other
# 2                            Program/Project Manager
# 3                                  Software Engineer
# 4                                 Research Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                          20+ years
# 3                                          1-3 years
# 4                                          20+ years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                                NaN
# 3                                             Python
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                SQL
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_4  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                  C
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_5  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                C++
# 3                                                C++
# 4                                                NaN
#
#                                            Q7_Part_6  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                               Java
# 3                                               Java
# 4                                                NaN
#
#                                            Q7_Part_7  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_8  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_9  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q7_Part_10  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q7_Part_11  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q7_Part_12  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             Q7_OTHER  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   Q8  \
# 0  What programming language would you recommend ...
# 1                                             Python
# 2                                             Python
# 3                                             Python
# 4                                             Python
#
#                                            Q9_Part_1  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q9_Part_2  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q9_Part_3  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q9_Part_4  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q9_Part_5  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                           PyCharm
# 4                                                NaN
#
#                                            Q9_Part_6  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           Spyder
#
#                                            Q9_Part_7  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                        Notepad++
# 3                                                NaN
# 4                                                NaN
#
#                                            Q9_Part_8  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q9_Part_9  \
# 0  Which of the following integrated development ...
# 1                                      Vim / Emacs
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q9_Part_10  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q9_Part_11  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                   Jupyter Notebook
# 3                                   Jupyter Notebook
# 4                                   Jupyter Notebook
#
#                                           Q9_Part_12  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             Q9_OTHER  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                              Other
# 4                                                NaN
#
#                                           Q10_Part_1  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                   Kaggle Notebooks
# 3                                   Kaggle Notebooks
# 4                                                NaN
#
#                                           Q10_Part_2  \
# 0  Which of the following hosted notebook product...
# 1                                    Colab Notebooks
# 2                                    Colab Notebooks
# 3                                                NaN
# 4                                    Colab Notebooks
#
#                                           Q10_Part_3  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q10_Part_4  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q10_Part_5  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q10_Part_6  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q10_Part_7  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q10_Part_8  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q10_Part_9  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_10  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_11  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_12  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_13  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_14  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_15  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q10_Part_16  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q10_OTHER  \
# 0  Which of the following hosted notebook product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  Q11  \
# 0  What type of computing platform do you use mos...
# 1                                           A laptop
# 2  A cloud computing platform (AWS, Azure, GCP, h...
# 3                                           A laptop
# 4  A cloud computing platform (AWS, Azure, GCP, h...
#
#                                           Q12_Part_1  \
# 0  Which types of specialized hardware do you use...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       NVIDIA GPUs
#
#                                           Q12_Part_2  \
# 0  Which types of specialized hardware do you use...
# 1                                 Google Cloud TPUs
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q12_Part_3  \
# 0  Which types of specialized hardware do you use...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q12_Part_4  \
# 0  Which types of specialized hardware do you use...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q12_Part_5  \
# 0  Which types of specialized hardware do you use...
# 1                                                NaN
# 2                                               None
# 3                                                NaN
# 4                                                NaN
#
#                                            Q12_OTHER  \
# 0  Which types of specialized hardware do you use...
# 1                                                NaN
# 2                                                NaN
# 3                                              Other
# 4                                                NaN
#
#                                                  Q13  \
# 0  Approximately how many times have you used a T...
# 1                                          2-5 times
# 2                                              Never
# 3                                              Never
# 4                                 More than 25 times
#
#                                           Q14_Part_1  \
# 0  What data visualization libraries or tools do ...
# 1                                        Matplotlib
# 2                                        Matplotlib
# 3                                        Matplotlib
# 4                                        Matplotlib
#
#                                           Q14_Part_2  \
# 0  What data visualization libraries or tools do ...
# 1                                           Seaborn
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_3  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_4  \
# 0  What data visualization libraries or tools do ...
# 1                                  Ggplot / ggplot2
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_5  \
# 0  What data visualization libraries or tools do ...
# 1                                             Shiny
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_6  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_7  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_8  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q14_Part_9  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q14_Part_10  \
# 0  What data visualization libraries or tools do ...
# 1                                  Leaflet / Folium
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q14_Part_11  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q14_OTHER  \
# 0  What data visualization libraries or tools do ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  Q15  \
# 0  For how many years have you used machine learn...
# 1                                         5-10 years
# 2                                       Under 1 year
# 3              I do not use machine learning methods
# 4                                         5-10 years
#
#                                           Q16_Part_1  \
# 0  Which of the following machine learning framew...
# 1                                      Scikit-learn
# 2                                      Scikit-learn
# 3                                                NaN
# 4                                      Scikit-learn
#
#                                           Q16_Part_2  \
# 0  Which of the following machine learning framew...
# 1                                        TensorFlow
# 2                                                NaN
# 3                                                NaN
# 4                                        TensorFlow
#
#                                           Q16_Part_3  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             Keras
#
#                                           Q16_Part_4  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q16_Part_5  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q16_Part_6  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q16_Part_7  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q16_Part_8  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q16_Part_9  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_10  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_11  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_12  \
# 0  Which of the following machine learning framew...
# 1                                             Caret
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_13  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_14  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_15  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_16  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q16_Part_17  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q16_OTHER  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_1  \
# 0  Which of the following ML algorithms do you us...
# 1                      Linear or Logistic Regression
# 2                      Linear or Logistic Regression
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_2  \
# 0  Which of the following ML algorithms do you us...
# 1                   Decision Trees or Random Forests
# 2                   Decision Trees or Random Forests
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_3  \
# 0  Which of the following ML algorithms do you us...
# 1  Gradient Boosting Machines (xgboost, lightgbm,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_4  \
# 0  Which of the following ML algorithms do you us...
# 1                                Bayesian Approaches
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_5  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_6  \
# 0  Which of the following ML algorithms do you us...
# 1                  Dense Neural Networks (MLPs, etc)
# 2                                                NaN
# 3                                                NaN
# 4                  Dense Neural Networks (MLPs, etc)
#
#                                           Q17_Part_7  \
# 0  Which of the following ML algorithms do you us...
# 1                      Convolutional Neural Networks
# 2                                                NaN
# 3                                                NaN
# 4                      Convolutional Neural Networks
#
#                                           Q17_Part_8  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q17_Part_9  \
# 0  Which of the following ML algorithms do you us...
# 1                          Recurrent Neural Networks
# 2                                                NaN
# 3                                                NaN
# 4                          Recurrent Neural Networks
#
#                                          Q17_Part_10  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q17_Part_11  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q17_OTHER  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q18_Part_1  \
# 0  Which categories of computer vision methods do...
# 1  General purpose image/video tools (PIL, cv2, s...
# 2                                                NaN
# 3                                                NaN
# 4  General purpose image/video tools (PIL, cv2, s...
#
#                                           Q18_Part_2  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Image segmentation methods (U-Net, Mask R-CNN,...
#
#                                           Q18_Part_3  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Object detection methods (YOLOv3, RetinaNet, etc)
#
#                                           Q18_Part_4  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Image classification and other general purpose...
#
#                                           Q18_Part_5  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q18_Part_6  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q18_OTHER  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q19_Part_1  \
# 0  Which of the following natural language proces...
# 1  Word embeddings/vectors (GLoVe, fastText, word...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q19_Part_2  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q19_Part_3  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q19_Part_4  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q19_Part_5  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               None
#
#                                            Q19_OTHER  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  Q20  \
# 0  In what industry is your current employer/cont...
# 1                          Manufacturing/Fabrication
# 2                          Manufacturing/Fabrication
# 3                                Academics/Education
# 4                                Academics/Education
#
#                                                  Q21  \
# 0  What is the size of the company where you are ...
# 1                                   50-249 employees
# 2                               1000-9,999 employees
# 3                               1000-9,999 employees
# 4                               1000-9,999 employees
#
#                                                  Q22  \
# 0  Approximately how many individuals are respons...
# 1                                                3-4
# 2                                                1-2
# 3                                                  0
# 4                                                  0
#
#                                                  Q23  \
# 0  Does your current employer incorporate machine...
# 1                      No (we do not use ML methods)
# 2  We are exploring ML methods (and may one day p...
# 3                                      I do not know
# 4                                      I do not know
#
#                                           Q24_Part_1  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q24_Part_2  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2  Build and/or run the data infrastructure that ...
# 3                                                NaN
# 4                                                NaN
#
#                                           Q24_Part_3  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q24_Part_4  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q24_Part_5  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q24_Part_6  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Do research that advances the state of the art...
#
#                                           Q24_Part_7  \
# 0  Select any activities that make up an importan...
# 1  None of these activities are an important part...
# 2                                                NaN
# 3  None of these activities are an important part...
# 4                                                NaN
#
#                                            Q24_OTHER  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  Q25  \
# 0  What is your current yearly compensation (appr...
# 1                                      25,000-29,999
# 2                                      60,000-69,999
# 3                                             $0-999
# 4                                      30,000-39,999
#
#                                                  Q26  \
# 0  Approximately how much money have you (or your...
# 1                                          $100-$999
# 2                                          $0 ($USD)
# 3                                          $0 ($USD)
# 4                                          $0 ($USD)
#
#                                         Q27_A_Part_1  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_2  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_3  \
# 0  Which of the following cloud computing platfor...
# 1                       Google Cloud Platform (GCP)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_4  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_5  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_6  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_7  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_8  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q27_A_Part_9  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q27_A_Part_10  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q27_A_Part_11  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                               None
# 4                                                NaN
#
#                                          Q27_A_OTHER  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  Q28  \
# 0  Of the cloud platforms that you are familiar w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q29_A_Part_1  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q29_A_Part_2  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q32_B_Part_20  \
# 0  Which of the following big data products (rela...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               None
#
#                                          Q32_B_OTHER  \
# 0  Which of the following big data products (rela...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_1  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                 Microsoft Power BI
# 4                                                NaN
#
#                                         Q34_B_Part_2  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_3  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                 Google Data Studio
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_4  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_5  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                            Tableau
# 4                                                NaN
#
#                                         Q34_B_Part_6  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_7  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_8  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                               Qlik
# 3                                                NaN
# 4                                                NaN
#
#                                         Q34_B_Part_9  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_10  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_11  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_12  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_13  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_14  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_15  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q34_B_Part_16  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               None
#
#                                          Q34_B_OTHER  \
# 0  Which of the following business intelligence t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q36_B_Part_1  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q36_B_Part_2  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q36_B_Part_3  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2  Automated model selection (e.g. auto-sklearn, ...
# 3  Automated model selection (e.g. auto-sklearn, ...
# 4                                                NaN
#
#                                         Q36_B_Part_4  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q36_B_Part_5  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q36_B_Part_6  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q36_B_Part_7  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               None
#
#                                          Q36_B_OTHER  \
# 0  Which categories of automated machine learning...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q37_B_Part_1  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                               Google Cloud AutoML
# 3                                                NaN
# 4                                                NaN
#
#                                         Q37_B_Part_2  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q37_B_Part_3  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q37_B_Part_4  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                  DataRobot AutoML
# 4                                                NaN
#
#                                         Q37_B_Part_5  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q37_B_Part_6  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q37_B_Part_7  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q37_B_OTHER  \
# 0  Which specific automated machine learning tool...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_1  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_2  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                       TensorBoard
# 4                                                NaN
#
#                                         Q38_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_11  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                               None
# 3                                                NaN
# 4                                               None
#
#                                          Q38_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## What are the 10 countries with the most respondents?

# %%
df = data_21.iloc[1:]['Q3'].value_counts()[:10]
ax = px.pie(df, values=df.values, names=list(df.index), 
             color_discrete_sequence=["#95101f","#a82820", "#ba3d1f","#cb511d", "#d45d00","#dc6818", "#e87a13","#f4900a","#ffa600", "#f6a800"], 
             hole=.35,
             title='Percentage of total respondents of top 10 countries in 2021',             
            )

ax.update_traces(hovertemplate = "%{label}: <b>%{value}</b>", textfont_size=14)
ax.update_layout(
    hoverlabel=dict(
        bgcolor="white",
#         font_size=16,
#         font_family="Serif",
    ),
    margin=dict(l=20, r=20, t=50, b=20),
#     title_font_family="Serif",
)
ax.show()
# Out:
# <div>                            <div id="53ff0758-5cbd-4649-985b-7b62a21273c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53ff0758-5cbd-4649-985b-7b62a21273c7")) {                    Plotly.newPlot(                        "53ff0758-5cbd-4649-985b-7b62a21273c7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.35,"hovertemplate":"%{label}: <b>%{value}</b>","labels":["India","United States of America","Other","Japan","China","Brazil","Russia","Nigeria","United Kingdom of Great Britain and Northern Ireland","Pakistan"],"legendgroup":"","name":"","showlegend":true,"values":[7434,2650,1270,921,814,751,742,702,550,530],"type":"pie","textfont":{"size":14}}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"} ...

# %% [markdown]
# ## Which machine learning algorithms are used frequently?

# %%
q18_dictionary_of_counts_2021 = {
    data_21['Q18_Part_1'][0].split('- ')[-1] : (data_21['Q18_Part_1'].count()),
    data_21['Q18_Part_2'][0].split('- ')[-1] : (data_21['Q18_Part_2'].count()),
    data_21['Q18_Part_3'][0].split('- ')[-1] : (data_21['Q18_Part_3'].count()),
    data_21['Q18_Part_4'][0].split('- ')[-1] : (data_21['Q18_Part_4'].count()),
    data_21['Q18_Part_5'][0].split('- ')[-1] : (data_21['Q18_Part_5'].count()),
    data_21['Q18_Part_6'][0].split('- ')[-1] : (data_21['Q18_Part_6'].count()),
    data_21['Q18_OTHER'][0].split('- ')[-1] : (data_21['Q18_OTHER'].count())
}
# q18_dictionary_of_counts_2021

# %%
q17_dictionary_of_counts_2021 = {
    data_21['Q17_Part_1'][0].split('- ')[-1] : (data_21['Q17_Part_1'].count()),
    data_21['Q17_Part_2'][0].split('- ')[-1] : (data_21['Q17_Part_2'].count()),
    data_21['Q17_Part_3'][0].split('- ')[-1] : (data_21['Q17_Part_3'].count()),
    data_21['Q17_Part_4'][0].split('- ')[-1] : (data_21['Q17_Part_4'].count()),
    data_21['Q17_Part_5'][0].split('- ')[-1] : (data_21['Q17_Part_5'].count()),
    data_21['Q17_Part_6'][0].split('- ')[-1] : (data_21['Q17_Part_6'].count()),
    data_21['Q17_Part_7'][0].split('- ')[-1] : (data_21['Q17_Part_7'].count()),
    data_21['Q17_Part_8'][0].split('- ')[-1] : (data_21['Q17_Part_8'].count()),
    data_21['Q17_Part_9'][0].split('- ')[-1] : (data_21['Q17_Part_9'].count()),
    data_21['Q17_Part_10'][0].split('- ')[-1] : (data_21['Q17_Part_10'].count()),
    data_21['Q17_Part_11'][0].split('- ')[-1] : (data_21['Q17_Part_11'].count()),
    data_21['Q17_OTHER'][0].split('- ')[-1] : (data_21['Q17_OTHER'].count())
}
# q17_dictionary_of_counts_2021

# %%
fig = px.scatter(
    x=q17_dictionary_of_counts_2021.keys(), 
    y=q17_dictionary_of_counts_2021.values(), 
    title='ML algorithms that are used on a regular basis',
    size=q17_dictionary_of_counts_2021.values(), 
    color_discrete_sequence=['#FF5F01'],
)
fig.update_layout(
    title={
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_size':20,
    },
    hoverlabel=dict(
    font_color="white",
)
    ,
    xaxis_title="ML Algorithms",
    yaxis_title="Number of respondants using the algorithms",
#     title_font_family="Serif",
    plot_bgcolor='rgba(0,0,0,0)'
    )
fig.show()
# Out:
# <div>                            <div id="20d1b747-b682-4998-8fdd-2e5e6475e35d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20d1b747-b682-4998-8fdd-2e5e6475e35d")) {                    Plotly.newPlot(                        "20d1b747-b682-4998-8fdd-2e5e6475e35d",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#FF5F01","size":[13853,11864,7567,4393,964,4469,7411,1354,4229,2274,1471,484],"sizemode":"area","sizeref":34.6325,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Linear or Logistic Regression","Decision Trees or Random Forests","Gradient Boosting Machines (xgboost, lightgbm, etc)","Bayesian Approaches","Evolutionary Approaches","Dense Neural Networks (MLPs, etc)","Convolutional Neural Networks","Generative Adversarial Networks","Recurrent Neural Networks","Transformer Networks (BERT, gpt-3, etc)","None","Other"],"xaxis":"x","y":[13853,11864,7567,4393,964,4469,7411,1354,4229,2274,1471,484],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77 ...

# %% [markdown]
# ## How many people aged below 50 are attented among the top 10 countries?

# %%
labels=['18-21', '22-24', '25-29', '30-34', '35-39', '40-44', '45-49']
tmp_df = data_21[data_21['Q3'].isin(data_21.iloc[1:]['Q3'].value_counts()[:10].index)][['Q1','Q2','Q3']]
tmp_df = tmp_df[tmp_df['Q1'].isin(labels)]
tmp_df.groupby(by=['Q3','Q1']).agg(['count'])['Q2'].unstack().fillna(value=0).plot(
    kind='barh', stacked=True,
    color=["#3B27BA","#E847AE", "#13CA91", "#FF9472", "#FE6B35","#D9EB4B", "#04005E"],
    )
# get rid of the frame
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
plt.title('Number of people aged less than 50 in top 10 countries', fontsize=9, color='#1b293f')
plt.legend(labels=labels, prop={'size':8})
plt.ylabel('')
plt.xticks(fontsize= 6)
plt.yticks(fontsize= 6)

plt.show()

# %% [markdown]
# ## Their coding experience

# %%
plt.figure(figsize=(20,8))

labels=['18-21', '22-24', '25-29', '30-34', '35-39', '40-44', '45-49']

tmp_df = data_21.drop(index=0)[data_21['Q1'].isin(labels)]
sns.countplot(x = 'Q6', hue = 'Q1', data = tmp_df, 
              palette=["#3B27BA","#E847AE", "#13CA91", "#FF9472", "#FE6B35","#D9EB4B", "#04005E"])
# get rid of the frame
for spine in plt.gca().spines.values():
    spine.set_visible(False)
# plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='on', labelbottom='on')
plt.title('Coding Experience', loc='center', y=1.1, fontsize=18)
plt.legend(prop={'size':14})
plt.xlabel('years of coding experience', fontsize=14)
plt.ylabel('number of respondant', fontsize=14)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()

# %% [markdown]
# ## Their machine learning experience

# %%
def create_map_df(df,col1,col2):
    
    df = df.iloc[1:]
    df.replace({col2:{'I do not use machine learning methods':'not use ML methods',
                     '20 or more years':'+20 years', 'Under 1 year':'>1 year'}}, inplace=True)
    df = pd.DataFrame(df[[col1, col2, 'Latitude', 'Longitude']]).groupby([col1, col2,'Latitude', 'Longitude']).size().reset_index(name='count')
    df[col2] = df[col2] + ": " + df['count'].astype(str)
    map_data = pd.DataFrame(df[col2].groupby([df[col1]]).apply(list).reset_index()) 
    map_data = pd.merge(map_data,df[[col1,'Latitude', 'Longitude']],on=col1, how='left')
    map_data = map_data.drop_duplicates(subset = [col1]).reset_index()
    
    world_map= folium.Map(tiles="Stamen Toner")
    mc = MarkerCluster()
    for idx, row in map_data.iterrows():
        if not math.isnan(row['Longitude']) and not math.isnan(row['Latitude']):
            tooltip = 'Click on it'
            popup_text = """
            Country : <b>%s</b><br>
            ML Experience : <b>%s</b><br>
            """ % (row['Q3'], row['Q15'])

#             iframe = folium.IFrame(html)
            popup = folium.Popup(popup_text,
                                 min_width=200,
                                 max_width=200)
        mc.add_child(Marker([row['Latitude'], row['Longitude']],tooltip=tooltip, popup=popup,
                            icon=folium.Icon(color='red',icon='info-sign')))
    
        world_map.add_child(mc)
    
    return world_map

df = pd.merge(data_21, map_df, on = 'Q3', how = 'left')
wmap = create_map_df(df, 'Q3', 'Q15')
wmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7c776c551867455c86158d5beb4e9870%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7c776c551867455c86158d5beb4e9870%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# ## How many years have the respondents used machine learning methods based on their job role?

# %%
def drawPieMarker(xs, ys, ratios, sizes, colors, ax):
    markers = []
    previous = 0
    # calculate the points of the pie pieces
    for color, ratio in zip(colors, ratios):
        this = 2 * np.pi * ratio + previous
        x  = [0] + np.cos(np.linspace(previous, this, 30)).tolist() + [0]
        y  = [0] + np.sin(np.linspace(previous, this, 30)).tolist() + [0]
        xy = np.column_stack([x, y])
        previous = this
        markers.append({'marker':xy, 's':np.abs(xy).max()**2*np.array(sizes), 'facecolor':color})

    # scatter each of the pie pieces to create pies
    for marker in markers:
        ax.scatter(xs, ys, **marker, alpha=0.7)


q5_order = ['Business Analyst',
            'Data Analyst',
            'Data Engineer',
            'Data Scientist',
            'DBA/Database Engineer',
            'Developer Relations/Advocacy',
            'Machine Learning Engineer',
            'Product Manager',
            'Program/Project Manager',
            'Research Scientist',
            'Software Engineer', 
            'Student',
            'Statistician',
            'Currently not employed',
            'Other']

q15_order = ['I do not use machine learning methods',
             'Under 1 year',
             '1-2 years',
             '2-3 years',
             '3-4 years',
             '4-5 years',
             '5-10 years',
             '10-20 years',
             '20 or more years']



# data_q5q15 = pd.pivot_table(data_21, values=['count'], index=['Q5'], columns=['Q15'], 
#                             aggfunc={'count':np.sum}).fillna(0).astype(int).loc[q5_order, q15_order].stack()

# aggregate basis cat data for age and gender
data_q5q15 = data_21.groupby(['Q5', 'Q15']).size().reset_index(name='count').rename(
    columns={
        'Q5': 'Role', 
        'Q15': 'ML_experience', 
    }).set_index('Role')

# data_q5q15_man = pd.pivot_table(data_21[data_21['Q2']=='Man'], values='count', index=['Q5'], 
#                                 columns=['Q15'], aggfunc=np.sum).fillna(0).astype(int).loc[q5_order, q15_order].stack()

data_q5q15_man = data_21[data_21['Q2']=='Man'].groupby(['Q5', 'Q15']).size().reset_index(name='count').rename(
    columns={
        'Q5': 'Role', 
        'Q15': 'ML_experience', 
    }).set_index('Role')

# data_q5q15_woman = pd.pivot_table(data_21[data_21['Q2']=='Woman'], values='count', index=['Q5'], 
#                                   columns=['Q15'], aggfunc=np.sum).fillna(0).astype(int).loc[q5_order, q15_order].stack()


data_q5q15_woman = data_21[data_21['Q2']=='Woman'].groupby(['Q5', 'Q15']).size().reset_index(name='count').rename(
    columns={
        'Q5': 'Role', 
        'Q15': 'ML_experience', 
    }).set_index('Role')

fig = plt.figure(figsize=(20, 37), dpi=200)

gs = fig.add_gridspec(5, 5)



ax_plot = fig.add_subplot(gs[1:4, 0:4]) 
for q5_idx in q5_order[::-1]:
    for q15_idx in q15_order:
#         man = data_q5q15_man[q5_idx][q15_idx]

        try:
            man = data_q5q15_man[data_q5q15_man['ML_experience'] == q15_idx].loc[q5_idx,'count']
        except KeyError:
            man = 1
#         woman = data_q5q15_woman[q5_idx][q15_idx]
        try:
            woman = data_q5q15_woman[data_q5q15_woman['ML_experience'] == q15_idx].loc[q5_idx,'count']
        except KeyError:
            woman = 1
#         tot = data_q5q15[q5_idx][q15_idx]
        try:
            tot = data_q5q15[data_q5q15['ML_experience'] == q15_idx].loc[q5_idx,'count']
        except KeyError:
            tot = 1
            
#         print('man', man, 'woman', woman,'total', tot)
        drawPieMarker([q15_idx],[q5_idx], [man/(man+woman), woman/(man+woman)] ,
                      [tot*2.5], ['#0096af', '#ee417f'], ax=ax_plot)



# Pos
ax_pos = fig.add_subplot(gs[0, :4], sharex=ax_plot) 
data_q15_woman = data_21[data_21['Q2']=='Woman']['Q15'].value_counts()[q15_order]
ax_pos.bar(data_q15_woman.index, data_q15_woman, width=0.45, alpha=0.7, color='#ee417f')

data_q15_man = data_21[data_21['Q2']=='Man']['Q15'].value_counts()[q15_order]
ax_pos.bar(data_q15_man.index, data_q15_man, bottom=data_q15_woman , width=0.45, alpha=0.7, color='#0096af')

plt.setp(ax_pos.get_xticklabels(), visible=False)


# Exp
ax_exp = fig.add_subplot(gs[1:4, 4], sharey=ax_plot) 

data_q5_woman = data_21[data_21['Q2']=='Woman']['Q5'].value_counts()[q5_order]
ax_exp.barh(data_q5_woman.index[::-1], data_q5_woman[::-1], height=0.55, alpha=0.7, color='#ee417f')

data_q5_man = data_21[data_21['Q2']=='Man']['Q5'].value_counts()[q5_order]
ax_exp.barh(data_q5_man.index[::-1], data_q5_man[::-1], left= data_q5_woman[::-1],height=0.55, alpha=0.7, color='#0096af')

plt.setp(ax_exp.get_yticklabels(), visible=False)

# Spines
for s in ['top', 'left', 'right', 'bottom']:
    ax_plot.spines[s].set_visible(False)
    ax_pos.spines[s].set_visible(False)
    ax_exp.spines[s].set_visible(False)
    
ax_plot.grid(linewidth=0.2, zorder=0)   
# ax_plot.set_aspect('equal')
q5_order.reverse()
ax_plot.set_yticklabels(q5_order,  fontsize=15)
ax_plot.set_xticklabels(q15_order, fontsize=15, rotation=90)

plt.title('Gender - Job Role - ML Experience', fontweight='bold', fontsize=25, color='#1b293f', y=1.3,x=0) 
# fig.text(0.8, 0.88, 'Stacked Bar Chart + Categorical Bubble Pie Chart', fontweight='light', fontfamily='serif', 
#          fontsize=20, ha='right')
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## What is the highest level of education that the respondents have attained or plan to attain within the next 2 years based on their gender?

# %%
# aggregate basis cat data for age and gender
agg_data = data_21[1:].groupby(['Q2', 'Q4']).size().reset_index(name='respondent_count')

agg_data = agg_data.rename(
    columns={
        'Q4': 'education', 
        'Q2': 'gender', 
    })
# agg_data.groupby('gender').head()

# %%
#Country Age and Average Salary chart
# sal_country=survey[survey['Q24'] !='No Data']
sal_country=agg_data.copy()
sal_country=sal_country.groupby(['gender', 'education']).agg('sum').reset_index()
# sal_country=sal_country.round({'Salary': 1, 'Average Age': 1})
fig = px.scatter(sal_country, x="education", y="gender", size="respondent_count", color="gender",
                 color_continuous_scale='inferno',title='Kaggle 2021: Average Age and Salary by Country (hover for details)',
           hover_name="gender",  size_max=40)
for annotation in fig.layout.annotations:
    annotation.text = annotation.text.split("=")[1]
    fig.update_xaxes(showticklabels=True)
    fig.layout.showlegend = False
fig.show()
# Out:
# <div>                            <div id="7e947ee3-697a-455c-8ed0-1e8521b358ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e947ee3-697a-455c-8ed0-1e8521b358ac")) {                    Plotly.newPlot(                        "7e947ee3-697a-455c-8ed0-1e8521b358ac",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>gender=%{y}<br>education=%{x}<br>respondent_count=%{marker.size}<extra></extra>","hovertext":["Man","Man","Man","Man","Man","Man","Man"],"legendgroup":"Man","marker":{"color":"#636efa","size":[7928,2171,445,7995,360,270,1429],"sizemode":"area","sizeref":4.996875,"symbol":"circle"},"mode":"markers","name":"Man","orientation":"v","showlegend":true,"x":["Bachelor’s degree","Doctoral degree","I prefer not to answer","Master’s degree","No formal education past high school","Professional doctorate","Some college/university study without earning a bachelor’s degree"],"xaxis":"x","y":["Man","Man","Man","Man","Man","Man","Man"],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>gender=%{y}<br>education=%{x}<br>respondent_count=%{marker.size}<extra></extra>","hovertext":["Nonbinary","Nonbinary","Nonbinary","Nonbinary","Nonbinary","Nonbinary","Nonbinary"],"legendgroup":"Nonbinary","marker":{"color":"#EF553B","size":[30,11,3,23,6,3,12],"sizemode":"area","sizeref":4.996875,"symbol":"circle"},"mode":"markers","name":"Nonbinary","orientation":"v","showlegend":true,"x":["Bachelor’s degree","Doctoral degree","I prefer not to answer","Master’s degree","No formal education past high school","Professional doctorate","Some college/university study without earning a bachelor’s degree"],"xaxis":"x","y":["Nonbinary","Nonbinary","Nonbinary","Nonbinary","Nonbinary","Nonbinary","Nonbinary"],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>gender=%{y}<br>education=%{x}<br>respondent_count=%{marker.size}<extra></extra>","hovertext":["Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say"],"legendgroup":"Prefer not to say","marker":{"color":"#00cc96","size":[91,44,36,151,5,6,22],"sizemode":"area","sizeref":4.996875,"symbol":"circle"},"mode":"markers","name":"Prefer not to say","orientation":"v","showlegend":true,"x":["Bachelor’s degree","Doctoral degree","I prefer not to answer","Master’s degree","No formal education past high school","Professional doctorate","Some college/university study without earning a bachelor’s degree"],"xaxis":"x","y":["Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say","Prefer not to say"],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>gender=%{y}<br>education=%{x}<br>respondent_count=%{marker.size}<extra></extra>","hovertext":["Prefer to self-describe","Prefer to self-describe","Prefer to self-describe","Prefer to self-describe","Prefer to self-describe","Prefer to self-describe"],"legendgroup":"Prefer to self-describe","marker":{"color":"#ab63fa","size":[15,4,3,13,2,5],"sizemode":"area","sizeref":4.996875,"symbol":"circle"},"mode":"markers","name":"Prefer to self-describe","orientation":"v","showlegend":true,"x":["Bachelor’s degree","Doctoral degree","I prefer not to answer","Master’s degree","No formal education past high school","Some college/university study without earning a bachelor’s degree"],"xaxis":"x","y":["Prefer to self-describe","Prefer to self-describe","Prefer to self-describe","Prefer to self-describe","Prefer to self-describe","Prefer to self-describe"],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>gender=%{y}<br>education=%{x}<br>respondent_count=%{marker.size}<extra></extra>","hovertext":["Wo ...

# %%
# Q2 Analysis
data = data_21.copy()
data['Q2'] = data['Q2'].apply(lambda x : 'ETC' if x not in ['Man', 'Woman'] else x)
data_q1q2 = data[data['Q2'] != 'ETC'].groupby(['Q2'])['Q1'].value_counts().unstack().sort_index()
man = data_q1q2.loc['Man']
woman = -data_q1q2.loc['Woman']

fig, ax = plt.subplots(1,1, figsize=(15, 10))
ax.bar(man.index, man, width=0.55, color='#0096af', alpha=0.8, label='Male')
ax.bar(woman.index, woman, width=0.55, color='#ee417f', alpha=0.8, label='Female')
ax.set_ylim(-1500, 4100)

for i in man.index:
    ax.annotate(f"{man[i]}", 
                   xy=(i, man[i] + 100),
                   va = 'center', ha='center',fontweight='light',color='#4a4a4a')# fontfamily='serif',
                   
    
for i in woman.index:
    ax.annotate(f"{-woman[i]}", 
                   xy=(i, woman[i] - 100),
                   va = 'center', ha='center',fontweight='light', color='#4a4a4a') #, fontfamily='serif',
                     

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)

ax.set_xticklabels(data_q1q2.columns,)# fontfamily='serif')
ax.set_yticks([])    
ax.legend()
fig.text(0.16, 0.95, 'Age / Gender Distribution', fontsize=15)#, fontweight='bold', fontfamily='serif')    
plt.show()

# %%
# Q2 Analysis
data = data_21.copy()
data['Q2'] = data['Q2'].apply(lambda x : 'ETC' if x not in ['Man', 'Woman'] else x)
q6_order = ['< 1 years', '1-3 years', '3-5 years', '5-10 years', '10-20 years',
           '20+ years', 'I have never written code']
data_q6q2 = data[data['Q2'] != 'ETC'].groupby(['Q2'])['Q6'].value_counts().unstack().sort_index()[q6_order]
man = data_q6q2.loc['Man']
woman = -data_q6q2.loc['Woman']

fig, ax = plt.subplots(1,1, figsize=(15, 10))
ax.bar(man.index, man, width=0.55, color='#0096af', alpha=0.8, label='Male')
ax.bar(woman.index, woman, width=0.55, color='#ee417f', alpha=0.8, label='Female')
ax.set_ylim(-2000, 6500)

for i in man.index:
    ax.annotate(f"{man[i]}", 
                   xy=(i, man[i] + 100),
                   va = 'center', ha='center',fontweight='light',color='#4a4a4a')# fontfamily='serif',
                   
    
for i in woman.index:
    ax.annotate(f"{-woman[i]}", 
                   xy=(i, woman[i] - 100),
                   va = 'center', ha='center',fontweight='light',color='#4a4a4a')# fontfamily='serif',
                  

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)

ax.set_xticklabels(data_q6q2.columns)#, fontfamily='serif')
ax.set_yticks([])    
ax.legend()
fig.text(0.16, 0.95, 'Years of coding experience / Gender Distribution', fontsize=15,) 
#         fontweight='bold', fontfamily='serif')    
plt.show()

# %% [markdown]
# ## Which activities are an important part of job?

# %%
# col_24 = [col for col in data_21.columns if 'Q24' in col]
# for c in col_24:
#     print(data_21.loc[1:,c].value_counts())

# %%
q24_dictionary_of_counts_2021 = {
    data_21['Q24_Part_1'][0].split('- ')[-1] : (data_21['Q24_Part_1'].count()-1),
    data_21['Q24_Part_2'][0].split('- ')[-1] : (data_21['Q24_Part_2'].count()-1),
    data_21['Q24_Part_3'][0].split('- ')[-1] : (data_21['Q24_Part_3'].count()-1),
    data_21['Q24_Part_4'][0].split('- ')[-1] : (data_21['Q24_Part_4'].count()-1),
    data_21['Q24_Part_5'][0].split('- ')[-1] : (data_21['Q24_Part_5'].count()-1),
    data_21['Q24_Part_6'][0].split('- ')[-1] : (data_21['Q24_Part_6'].count()-1),
    data_21['Q24_Part_7'][0].split('- ')[-1] : (data_21['Q24_Part_7'].count()-1),
    data_21['Q24_OTHER'][0].split('- ')[-1] : (data_21['Q24_OTHER'].count()-1)
}
# q24_dictionary_of_counts_2021

# %%
colors = ['#004c6d', '#296080', '#437594', '#5d8ba9', '#75a1be', '#8eb8d3', '#a7cfe9', '#c1e7ff']
# colors = ['#003f5c', '#2f4b7c', '#665191', '#a05195', '#d45087', '#f95d6a', '#ff7c43', '#ffa600']

fig, ax = plt.subplots(1,1, figsize=(12, 6))
q24_dictionary_of_counts_2021 = dict(sorted(q24_dictionary_of_counts_2021.items(), key=lambda item: item[1], reverse=True))
ax.bar(q24_dictionary_of_counts_2021.keys(), q24_dictionary_of_counts_2021.values(), width=0.55, 
       edgecolor='darkgray', color=colors,
       linewidth=0.7)

for i in q24_dictionary_of_counts_2021.keys():
    ax.annotate(f"{q24_dictionary_of_counts_2021[i]}", 
                   xy=(i, q24_dictionary_of_counts_2021[i] + 300),
                   va = 'center', ha='center',fontweight='light', #fontfamily='serif',
                   color='#4a4a4a')


for s in ['top', 'left', 'right']:
    ax.spines[s].set_visible(False)
labels = ['Analyze data to influence product/decisions', 'Build prototypes to apply ML to new areas',
'Build the data infrastructure for data',
'Experimentation to improve existing ML models', 'Build ML service that to improve product or workflows',
'Do research that advances the SOA of ML', 'None of these activities', 'Other']

ax.set_xticklabels(labels, rotation=80) #fontfamily='serif',)
plt.title('Activities that make up an important part of your role at work', fontsize=15,)# fontweight='bold', fontfamily='serif')    
ax.grid(axis='y', linestyle='-', alpha=0.4)    
plt.show()

# %% [markdown]
# ## Which cloud computing platforms is used on a regular basis?

# %%
q27_A_dictionary_of_counts_2021 = {
    data_21['Q27_A_Part_1'][0].split('- ')[-1].split('(')[-1].replace(')','') : (data_21['Q27_A_Part_1'].count()),
    data_21['Q27_A_Part_2'][0].split('- ')[-1] : (data_21['Q27_A_Part_2'].count()),
    data_21['Q27_A_Part_3'][0].split('- ')[-1].split('(')[-1].replace(')','') : (data_21['Q27_A_Part_3'].count()),
    data_21['Q27_A_Part_4'][0].split('- ')[-1] : (data_21['Q27_A_Part_4'].count()),
    data_21['Q27_A_Part_5'][0].split('- ')[-1] : (data_21['Q27_A_Part_5'].count()),
    data_21['Q27_A_Part_6'][0].split('- ')[-1] : (data_21['Q27_A_Part_6'].count()),
    data_21['Q27_A_Part_7'][0].split('- ')[-1] : (data_21['Q27_A_Part_7'].count()),
    data_21['Q27_A_Part_8'][0].split('- ')[-1] : (data_21['Q27_A_Part_8'].count()),
    data_21['Q27_A_Part_9'][0].split('- ')[-1] : (data_21['Q27_A_Part_9'].count()),
    data_21['Q27_A_Part_10'][0].split('- ')[-1] : (data_21['Q27_A_Part_10'].count()),
    data_21['Q27_A_Part_11'][0].split('- ')[-1] : (data_21['Q27_A_Part_11'].count()),
    data_21['Q27_A_OTHER'][0].split('- ')[-1] : (data_21['Q27_A_OTHER'].count())
}
# q27_A_dictionary_of_counts_2021

# %%
im = Image.open('data/mask-removebg-preview.jpg')
img = np.array(im)

wc = WordCloud(width=img.shape[1],
               height=img.shape[0], random_state=42, background_color='white', # font_path=font_path
               collocations=False, colormap="Dark2", mask=img,
               contour_width=3, contour_color='steelblue')

wc.generate_from_frequencies(q27_A_dictionary_of_counts_2021)
plt.figure(dpi=500)
plt.imshow(wc, interpolation='bilinear') 
plt.axis("off")
plt.tight_layout()  
plt.show()

# %% [markdown]
# I learned a lot from these notebooks:
#
# * https://www.kaggle.com/paultimothymooney/2021-survey-job-title-data-scientist/notebook
# * https://www.kaggle.com/ruchi798/kaggle-ml-ds-survey-analysis/notebook
# * https://www.kaggle.com/paultimothymooney/2021-kaggle-data-science-machine-learning-survey/notebook
# * https://www.kaggle.com/subinium/kaggle-2020-visualization-analysis/notebook
